# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
df = pd.read_csv("TaskOneDataset.csv")

# %%
df.head(100)
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0   17:02:00      Monday              18-30          Male   Above high school
# 1   17:02:00      Monday              31-50          Male  Junior high school
# 2   17:02:00      Monday              18-30          Male  Junior high school
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 4    1:06:00      Sunday              18-30          Male  Junior high school
# ..       ...         ...                ...           ...                 ...
# 95  17:35:00    Thursday              18-30          Male  Junior high school
# 96  17:35:00    Thursday              18-30          Male  Junior high school
# 97  17:35:00    Thursday              31-50          Male  Junior high school
# 98  20:50:00      Sunday              18-30       Unknown  Junior high school
# 99  20:50:00      Sunday            Over 51          Male  Junior high school
#
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
df['Educational_level'].unique()
# Out:
# array(['Above high school', 'Junior high school', nan,
#        'Elementary school', 'High school', 'Unknown', 'Illiterate',
#        'Writing & reading'], dtype=object)

# %%
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# This dataset contains 12316 rows and 32 columns.

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
# df.dropna(subset=['Educational_level'], inplace=True)
# df.dropna(subset=['Vehicle_driver_relation'], inplace=True)
                  
#Educational_level  
df['Educational_level'].fillna(df['Educational_level'].mode()[0], inplace =True)
#Vehicle_driver_relation
df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0], inplace =True)
#Driving_experience
df['Driving_experience'].fillna(df['Driving_experience'].mode()[0], inplace =True)
#Type_of_vehicle
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0], inplace =True)
#Owner_of_vehicle
df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0], inplace =True)
#Service_year_of_vehicle
df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0], inplace =True)
#Defect_of_vehicle
df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode()[0], inplace =True)
#Area_accident_occured
df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0], inplace =True)
#Lanes_or_Medians
df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0], inplace =True)
#Road_allignment 
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0], inplace =True)
#Types_of_Junction
df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0], inplace =True)
#Road_surface_type 
df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0], inplace =True)
#Type_of_collision
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0], inplace =True)
# Vehicle_movement
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0], inplace =True)
#Work_of_casuality
df['Work_of_casuality'].fillna(df['Work_of_casuality'].mode()[0], inplace =True)
#Fitness_of_casuality
df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0], inplace =True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# Now there is no any NULL values.

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Casualty_class'] = df['Casualty_class'].str.replace('na','')

df['Sex_of_casualty'] = df['Sex_of_casualty'].str.replace('na','')

df['Age_band_of_casualty'] = df['Age_band_of_casualty'].str.replace('na','')

df['Casualty_severity'] = df['Casualty_severity'].str.replace('na','')

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'])
df['Day_of_week'] = df['Day_of_week'].astype('str')
df['Accident_severity'] = df['Accident_severity'].astype('category')
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].astype('category')
df['Work_of_casuality'] = df['Work_of_casuality'].astype('category')
df['Casualty_severity'] = df['Casualty_severity'].astype('category')
df['Sex_of_casualty'] = df['Sex_of_casualty'].astype('category')
df['Casualty_class'] = df['Casualty_class'].astype('category')
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].astype('category')
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].astype('category')
df['Educational_level'] = df['Educational_level'].astype('category')
df['Sex_of_driver'] = df['Sex_of_driver'].astype('category')

# %% [markdown]
# converted 'Time' from Object to Datatime
# , 'Day_of_week' from Object to String as so on

# %%
df.dtypes
# Out:
# Time                           datetime64[ns]
# Day_of_week                            object
# Age_band_of_driver                     object
# Sex_of_driver                        category
# Educational_level                    category
# Vehicle_driver_relation              category
# Driving_experience                     object
# Type_of_vehicle                        object
# Owner_of_vehicle                     category
# Service_year_of_vehicle                object
# Defect_of_vehicle                      object
# Area_accident_occured                  object
# Lanes_or_Medians                       object
# Road_allignment                        object
# Types_of_Junction                      object
# Road_surface_type                      object
# Road_surface_conditions                object
# Light_conditions                       object
# Weather_conditions                     object
# Type_of_collision                      object
# ...

# %%
df.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0 2024-07-25 17:02:00      Monday              18-30          Male
# 1 2024-07-25 17:02:00      Monday              31-50          Male
# 2 2024-07-25 17:02:00      Monday              18-30          Male
# 3 2024-07-25 01:06:00      Sunday              18-30          Male
# 4 2024-07-25 01:06:00      Sunday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0           Automobile            Owner              Above 10yr  ...
# ...

# %%
df['Sex_of_driver'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.sample(2)
# Out:
#                      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 10808 2024-07-25 11:30:00     Tuesday           Under 18          Male
# 1702  2024-07-25 15:40:00      Sunday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 10808   Above high school                Employee             5-10yr
# 1702   Junior high school                Employee             5-10yr
#
#          Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 10808  Public (12 seats)            Owner                  2-5yrs  ...
# 1702          Automobile            Owner                 Unknown  ...
#
#           Vehicle_movement   Casualty_class Sex_of_casualty  \
# 10808      Moving Backward  Driver or rider            Male
# 1702   Entering a junction  Driver or rider            Male
#
#       Age_band_of_casualty Casualty_severity Work_of_casuality  \
# 10808                18-30                 3            Driver
# ...

# %%
df.tail()
# Out:
#                      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311 2024-07-25 16:15:00   Wednesday              31-50          Male
# 12312 2024-07-25 18:00:00      Sunday            Unknown          Male
# 12313 2024-07-25 13:55:00      Sunday            Over 51          Male
# 12314 2024-07-25 13:55:00      Sunday              18-30        Female
# 12315 2024-07-25 13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311  Junior high school                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# ...

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.histplot(df['Age_band_of_driver'],kde=True,bins=20,color='blue')
plt.title('The distribution for Age_band_of_driver')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Type_of_vehicle'],kde=True,bins=20,color='blue')
plt.title('The distribution for Type_of_vehicle')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Educational_level'],kde=True,bins=20,color='blue')
plt.title('The distribution for Age_band_of_driver')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Driving_experience'],kde=True,bins=20,color='blue')
plt.title('The distribution for Driving_experience')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Age_band_of_driver',y='Accident_severity')
plt.title('The Relationships between Age_band_of_driver & Accident_severity' )
plt.show()

# %%
df.corr(numeric_only=True)
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title('The Relationships between Age_band_of_driver & Accident_severity' )
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.pairplot(df)

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Cause_of_accident',y='Day_of_week')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Vehicle_driver_relation'],kde=True,bins=20,color='blue')
plt.title('Vehicle_driver_relation')
plt.show()

# %%
df.corr(numeric_only=True)
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# The analysis sheds light on the multifaceted nature of factors contributing to road accidents. These include driver age, the day and time of the week, road and weather conditions, vehicle types, and individual driver characteristics. Recognizing these patterns can guide the development of tailored interventions and safety measures to mitigate the frequency and impact of road collisions. Potential approaches may involve upgrading road infrastructure, enhancing vehicle safety features, and promoting safe driving behaviors across all road users. Additionally, it is crucial to challenge stereotypes and adopt gender-neutral strategies in road safety efforts.
